# %% [markdown]
# <a href="https://colab.research.google.com/github/nephelim74/machinelearn/blob/main/lect2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
6
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])
y1 = np.array([1, 2, 3, 4, 5])
y2 = np.array([1, 1, 4, 9, 0])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(x, y, s=30)
plt.plot(x, y1, 'g')
plt.plot(x, y2, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
err1 = sum(y1-y)
err2 = sum(y2-y)
print('ошибка err1:', err1)
print('ошибка err2:', err2)
# Out:
# ошибка err1: 0
# ошибка err2: 0

# %%
err1 = sum((y1-y)**2)
err2 = sum((y2-y)**2)
print('ошибка err1:', err1)
print('ошибка err2:', err2)
# Out:
# ошибка err1: 0
# ошибка err2: 52

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
np.random.seed(0) # для воспроизведения результатов
x = np.random.rand(1000, 1)
y = 1 + 3 * x + np.random.randn(1000, 1)
d = {'x': x.reshape(1,1000)[0], 'y': y.reshape(1,1000)[0]}
df = pd.DataFrame(data=d)
df.head()
# Out:
#           x         y
# 0  0.548814  2.544743
# 1  0.715189  3.164847
# 2  0.602763  4.657881
# 3  0.544883  2.420483
# 4  0.423655  1.771948

# %%
plt.scatter(df['x'], df['y'], s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, train_size=0.7, random_state=123) # 70 % обучающая train и 30 тестовая test

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression().fit(train[['x']], train[['y']])

# %%
print('w_0:', model.intercept_)
print('w_1:', model.coef_)
# Out:
# w_0: [1.08258227]
# w_1: [[2.84716323]]

# %%
y_predict_train = model.predict(train[['x']])
print(y_predict_train[:, 0][:10])
# Out:
# [1.78985595 1.45860173 2.99601208 2.15810342 3.66369375 1.16785573
#  1.80559558 1.45979619 1.11593418 2.08447907]

# %%
y_predict_train = model.intercept_ + model.coef_ * train[['x']]
print(y_predict_train[:10])
# Out:
#             x
# 498  1.789856
# 243  1.458602
# 314  2.996012
# 202  2.158103
# 300  3.663694
# 682  1.167856
# 230  1.805596
# 306  1.459796
# 166  1.115934
# 620  2.084479

# %%
plt.plot(train['x'], y_predict_train, linewidth=4, c='g')
plt.scatter(train['x'], train['y'], s=10, c='b')
plt.scatter(test['x'], test['y'], s=10, c='r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
